# %%
import sys, os
sys.path.append('../interpreters')
import lime
from lime import lime_image
import numpy as np
import glob as gb
import cv2
import matplotlib.pyplot as plt
sys.path.append('../biteam/src/utils')
import preprocessor as preprocess
import keras
from keras.models import load_model
print('Notebook run using keras:', keras.__version__)
from sklearn.metrics import confusion_matrix


# %matplotlib inline
# Out:
# Using TensorFlow backend.
# Notebook run using keras: 2.0.5

# %% [markdown]
# # Configuration and Display #

# %%
emotion_labels = {0:'angry',1:'disgust',2:'fear',3:'happy', 4:'sad',5:'surprise',6:'neutral'} 
wanted = 6       # want to check this emotion
n_samples = 30   # number of samples to display

# %% [markdown]
# # Load trained model #

# %%
# name-batch-accuracy
emotion_model_path = '../biteam/trained_models/emotion_models/fer2013_mini_XCEPTION.hdf5'
emotion_classifier = load_model(emotion_model_path, compile=False)

# %% [markdown]
# # Get model configuration #

# %%
emotion_target_size = emotion_classifier.input_shape[1:3]
print(emotion_target_size)
# Out:
# (64, 64)

# %% [markdown]
# # Read images for testing #

# %%
acc_pred = []
y_softmax = []
y_pred = []
y_true = []
y_file = []
folder = '../dataset/kaggle/fer2013/PrivateTest/'
for i in range(len(emotion_labels)):
    # read file in each emotion folder 
    filepath  = os.path.join(folder,str(i),'*.jpg')
    filenames = gb.glob(filepath)
    N_test = len(filenames)
    # making a prediction for this emotion i
    hit = 0
    for img_file in filenames: 
        
        # read data and normalised it as trained
        img = preprocess._imread(img_file)
        img = preprocess._imresize(img,emotion_target_size)
        img = preprocess.preprocess_input(img)
        # 4D reshape tensor
        img_data = np.expand_dims(img, 0)
        img_data = np.expand_dims(img_data, -1)
        # prediction
        preds = emotion_classifier.predict(img_data) 
        # decode to a predicted label
        emotion_pred = np.argmax(preds)
        emotion_true = i
        
        if (emotion_pred == emotion_true):
            hit +=1
        
        # record data: prediction and softmax     
        y_pred.append(emotion_pred)
        y_true.append(emotion_true)
        y_softmax.append(preds[0])
        y_file.append(img_file)
   
    # compute accuracy
    accuracy = hit/N_test        
    print('Class accuracy: {a:s} = {b:0.4f}'.format( a=emotion_labels[emotion_true], b=accuracy ) )
    acc_pred.append(accuracy)

# mean accuracy for all images
print('Mean accuracy for prediction = ', np.mean(acc_pred))
# Out:
# Class accuracy: angry = 0.5621
# Class accuracy: disgust = 0.5455
# Class accuracy: fear = 0.4053
# Class accuracy: happy = 0.8840
# Class accuracy: sad = 0.5354
# Class accuracy: surprise = 0.7380
# Class accuracy: neutral = 0.7045
# Mean accuracy for prediction =  0.624948842062

# %% [markdown]
# # Build 4D image data #

# %%
def Build_Data(image, target_size):
    # build data for the train model (resize and normalise scale) 
    img = preprocess._imresize(image,target_size)
    img = preprocess.preprocess_input(img)
    # 4D reshape tensor
    img_data = np.expand_dims(img, 0)
    img_data = np.expand_dims(img_data, -1)
    # make 3 channels data for lime- make 3 channel data
    image_stack = np.append(img_data, img_data[...,0,None], axis=-1)
    image_stack = np.append(image_stack, img_data[...,0,None], axis=-1)
    image_stack = image_stack.astype('float32')
    image_stack = np.asarray(image_stack)
    return image_stack

# %%
from skimage.segmentation import mark_boundaries

# %%
                #                     RIGHT/WRONG ANALYSIS FROM A CONFUSION MATRIX              #
                # ----------------------------------------------------------------------------- #  
                #  - Case 5: Right prediction                                                   #
                #  - Case 6: Wrong prediction (the highest wrong prediction label)              #
                #------------------------------------------------------------------------------ #

# %%
cf_matrix = confusion_matrix(y_true, y_pred)
print(emotion_labels)
print("----------- Prediction ----------------")
print(cf_matrix)
# Out:
# {0: 'angry', 1: 'disgust', 2: 'fear', 3: 'happy', 4: 'sad', 5: 'surprise', 6: 'neutral'}
# ----------- Prediction ----------------
# [[276   8  48  20  71   9  59]
#  [ 13  30   5   2   2   0   3]
#  [ 60   5 214  19 113  60  57]
#  [  9   1  15 777  33  17  27]
#  [ 55   1  53  30 318   7 130]
#  [ 13   1  49  25  10 307  11]
#  [ 26   1  29  35  84  10 441]]

# %%
# find the worst of the wrong predicition
cf_sort = np.argsort(cf_matrix[wanted,:])    #min to max
wrong_pred_idx = cf_sort[-2]
print("worst wrong indx: ", wrong_pred_idx)
# Out:
# worst wrong indx:  4

# %%
case5_list = [] #right prediction 
case6_list = [] #wrong prediciton on the worst case class
for i in range(len(y_pred)):
    label_true  = y_true[i]
    # pick this class for the evaluation
    if(label_true == wanted):
        label_pred  = y_pred[i]
        label_sfmax = y_softmax[i]
        # get prediction state: right
        pred_state = (label_pred == label_true)
        if(pred_state):
            case5_list.append(i)
        # get prediction state: wrong
        else:
            # get the worst wrong prediction
            if label_pred == wrong_pred_idx:
                case6_list.append(i)

print("Case5:Right prediction ",len(case5_list))
print("Case6:Wrong prediction ",len(case6_list))
# Out:
# Case5:Right prediction  441
# Case6:Wrong prediction  84

# %%
image_data = []
max_length = min(len(case5_list), n_samples)
for i in range(max_length):
    f_indx = case5_list[i]
    case_img = preprocess._imread(y_file[f_indx])
    case_data = Build_Data(case_img, emotion_target_size)
    image_data.append(case_data)
    print(y_file[f_indx])
    
right_explanation_out = []
right_segmentation_out = []
explainer = lime_image.LimeImageExplainer(data_channel='gray')
for i in range(max_length):
    lime_input = image_data[i]
    # Hide color is the color for a superpixel turned OFF.
    # Alternatively, if it is NONE, the superpixel will be replaced by the average of its pixels
    explanation,segments_img = explainer.explain_instance(lime_input[0], emotion_classifier.predict, top_labels=7, \
                                             hide_color=0, num_samples=1000,num_features=500, qs_kernel_size=2)
    
    right_explanation_out.append(explanation)
    right_segmentation_out.append(segments_img)
# Out:
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_69935039.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_90622972.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_6660913.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_86332873.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_94569971.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_99884816.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_40054829.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_20497417.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_72508807.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_13250695.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_31709955.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_79047478.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_6064339.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_40253004.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_48491783.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_47001839.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_95049878.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_49220838.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_58220596.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_72421730.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_77831423.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_35752207.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_50149350.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_87162312.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_97693600.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_82153759.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_88870687.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_74846355.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_12716854.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_53977336.jpg

# %%
image_data[1][0].shape
# Out:
# (64, 64, 3)

# %% [markdown]
# # LIME Analysis #

# %%
                                   
                                   
                                             ##  RIGHT PREDICTION  ##

# %%
print("Ground truth label: {a:s}".format(a=emotion_labels[wanted]))
plt.figure(figsize=(30,30))
for i in range(max_length):
    img = image_data[i][0]
    plt.subplot(int(max_length/7 + 1),7,i+1)
    plt.imshow(img/2+0.5)
# Out:
# Ground truth label: neutral

# %%
print("SHOW POSITIVE/NEGATIVE FEATURES IMAGE OVERLAY")
print("Ground truth image: {a:s} ----> Prediction: {a:s}".format(a=emotion_labels[wanted]))
plt.figure(figsize=(30,30))
for i in range(max_length):
    explanation = right_explanation_out[i]
    temp, mask = explanation.get_image_and_mask(wanted, positive_only=False, num_features=3, hide_rest=False)
    plt.subplot(int(max_length/7 + 1),7,i+1)
    plt.imshow(mark_boundaries(temp/2+0.5, mask))
# Out:
# SHOW POSITIVE/NEGATIVE FEATURES IMAGE OVERLAY
# Ground truth image: neutral ----> Prediction: neutral

# %%
print("ONLY SHOW POSITIVE FEATURES")
print("Ground truth image: {a:s} ----> Prediction: {a:s}".format(a=emotion_labels[wanted]))
plt.figure(figsize=(30,30))
for i in range(max_length):
    explanation = right_explanation_out[i]
    temp, mask = explanation.get_image_and_mask(wanted, positive_only=True, num_features=3, hide_rest=True)
    plt.subplot(int(max_length/7)+1,7,i+1)
    plt.imshow(mark_boundaries(temp/2+0.5, mask))
# Out:
# ONLY SHOW POSITIVE FEATURES
# Ground truth image: neutral ----> Prediction: neutral

# %%
                                            
                                            
                                        ##  WRONG PREDICTION  ##

# %%
image_data = []
max_length = min(len(case6_list), n_samples)
for i in range(max_length):
    f_indx = case6_list[i]
    case_img = preprocess._imread(y_file[f_indx])
    case_data = Build_Data(case_img, emotion_target_size)
    image_data.append(case_data)
    print(y_file[f_indx])
    
wrong_explanation_out = []
wrong_segmentation_out = []
explainer = lime_image.LimeImageExplainer(data_channel='gray')
for i in range(max_length):
    lime_input = image_data[i]
    # Hide color is the color for a superpixel turned OFF.
    # Alternatively, if it is NONE, the superpixel will be replaced by the average of its pixels
    explanation,segments_img = explainer.explain_instance(lime_input[0], emotion_classifier.predict, top_labels=7, \
                                             hide_color=0, num_samples=1000,num_features=500, qs_kernel_size=2)
    
    wrong_explanation_out.append(explanation)
    wrong_segmentation_out.append(segments_img)
# Out:
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_1522306.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_37241172.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_25282220.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_82574903.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_98615414.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_67307882.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_76929409.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_73082695.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_27659561.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_18697102.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_68489529.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_51397796.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_90735094.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_26425695.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_14061554.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_97194890.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_5724660.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_23116738.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_66690525.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_12586823.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_97400412.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_28110452.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_20488541.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_8524022.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_31095001.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_75945872.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_78761066.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_63492709.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_95723973.jpg
# ../dataset/kaggle/fer2013/PrivateTest/6/PrivateTest_63707088.jpg

# %%
print("Ground truth label: {a:s}".format(a=emotion_labels[wanted]))
plt.figure(figsize=(30,30))
for i in range(max_length):
    img = image_data[i][0]
    plt.subplot(int(max_length/7 + 1),7,i+1)
    plt.imshow(img/2+0.5)
# Out:
# Ground truth label: neutral

# %%
print("SHOW POSITIVE/NEGATIVE FEATURES IMAGE OVERLAY")
print("Ground truth image: {a:s} ----> Prediction: {b:s}".format(a=emotion_labels[wanted],\
                                                                 b=emotion_labels[wrong_pred_idx]))
plt.figure(figsize=(30,30))
for i in range(max_length):
    explanation = wrong_explanation_out[i]
    temp, mask = explanation.get_image_and_mask(wrong_pred_idx, positive_only=False, num_features=3, hide_rest=False)
    plt.subplot(int(max_length/7 +1),7,i+1)
    plt.imshow(mark_boundaries(temp/2+0.5, mask))
# Out:
# SHOW POSITIVE/NEGATIVE FEATURES IMAGE OVERLAY
# Ground truth image: neutral ----> Prediction: sad

# %%
print("ONLY SHOW POSITIVE FEATURES")
print("Ground truth image: {a:s} ----> Prediction: {b:s}".format(a=emotion_labels[wanted],\
                                                                 b=emotion_labels[wrong_pred_idx]))
plt.figure(figsize=(30,30))
for i in range(max_length):
    explanation = wrong_explanation_out[i]
    temp, mask = explanation.get_image_and_mask(wrong_pred_idx, positive_only=True, num_features=3, hide_rest=True)
    plt.subplot(int(max_length/7+1),7,i+1)
    plt.imshow(mark_boundaries(temp/2+0.5, mask))
# Out:
# ONLY SHOW POSITIVE FEATURES
# Ground truth image: neutral ----> Prediction: sad
